# %%
#check the number is even or odd
num=int(input("enter any number:"))
if num%2==0:
    print("this is even number")
else:
    print("this is odd numbmer")
# Out:
# enter any number: 24
# this is even number

# %%
#Write a code that accepts a sequence of words as input and prints the words in a sequence after sorting them alphabetically

input_string = input("Enter a sequence of words: ")
words = [word.lower() for word in input_string.split()]
words.sort()
print("The sorted words are:")
for word in words:
   print(word)
# Out:
# Enter a sequence of words:  raja is a bad guy
# The sorted words are:
# a
# bad
# guy
# is
# raja

# %%
#Writeaprogram,which willfindallthenumbersbetween1000and3000(both included) such that each digit of a number is an even number. The numbers obtained should be printed in a comma-separatedsequence on a single line.
def find_even_digit_numbers(start, end):
    even_digit_numbers = []
    for num in range(start, end + 1):
        num_str = str(num)
        if all(int(digit) % 2 == 0 for digit in num_str):
            even_digit_numbers.append(num_str)
    return ','.join(even_digit_numbers)

start = 1000
end = 3000
result = find_even_digit_numbers(start, end)
print(result)
# Out:
# 2000,2002,2004,2006,2008,2020,2022,2024,2026,2028,2040,2042,2044,2046,2048,2060,2062,2064,2066,2068,2080,2082,2084,2086,2088,2200,2202,2204,2206,2208,2220,2222,2224,2226,2228,2240,2242,2244,2246,2248,2260,2262,2264,2266,2268,2280,2282,2284,2286,2288,2400,2402,2404,2406,2408,2420,2422,2424,2426,2428,2440,2442,2444,2446,2448,2460,2462,2464,2466,2468,2480,2482,2484,2486,2488,2600,2602,2604,2606,2608,2620,2622,2624,2626,2628,2640,2642,2644,2646,2648,2660,2662,2664,2666,2668,2680,2682,2684,2686,2688,2800,2802,2804,2806,2808,2820,2822,2824,2826,2828,2840,2842,2844,2846,2848,2860,2862,2864,2866,2868,2880,2882,2884,2886,2888

# %%
#count the number and letters
s = input("Input a string")
d = l = 0
for c in s:
    if c.isdigit(): 
        d = d + 1
    elif c.isalpha(): 
        l = l + 1
    else:   
        pass
print("Letters", l)
print("Digits", d)
# Out:
# Input a string hjkhlj56
# Letters 6
# Digits 2

# %%
# Function to check if a number is palindrome or not
def is_palindrome(num):
   num_str = str(num)
     reversed_str = num_str[::-1]
     if num_str == reversed_str:
        return True
    else:
        return False
num = int(input("Enter a number: "))

if is_palindrome(num):
    print(num, "is a palindrome")
else:
    print(num, "is not a palindrome")
# Out:
# Enter a number:  121
# 121 is a palindrome
