# %%
print('Welcome To DS Training')
# Out:
# Welcome To DS Training

# %% [markdown]
# ### Syntax of Python
#
# ![image.png](attachment:0993d0bc-53cc-4724-b433-93d7514a521a.png)

# %%
a = 10
print(a)  # Datatype will get assigned at runtime
print(type(a))
# Out:
# 10
# <class 'int'>

# %%
a = 10.50
print(a)  # Datatype will get assigned at runtime
print(type(a))
# Out:
# 10.5
# <class 'float'>

# %%
a = 'Training'
print(a)  # Datatype will get assigned at runtime
print(type(a))
# Out:
# Training
# <class 'str'>

# %%
'''
Welcome 
To 
DataScience
training
'''

# %% [markdown]
# ### Python Tokens
#
# ![image.png](attachment:1a51deb4-9aab-4b66-a28e-d465129d7d89.png)

# %%
# Sum of Two Numbers in python
a = 10
b = 20
c = a + b
print('total =', c)

# Literals :  10 and 20 
# Operators :  + =
# Identifier: a b c 
# Keyworkds : print,  if,  for, break, continue  (Reserved Words )
# Out:
# total = 30

# %%
a = 10
b = 20.5
c = a + b
print('total =', c)
# Out:
# total = 30.5

# %%
a = 10
b = 'Welcome'
c = a + b
print('total =', c)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 3
#       1 a = 10
#       2 b = 'Welcome'
# ----> 3 c = a + b
#       4 print('total =', c)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %% [markdown]
# ### Variables
#
# ![image.png](attachment:f3818eb3-cba6-408e-ab66-04596d20702a.png)

# %%
num = 5
num
# Out:
# 10

# %% [markdown]
# ### Rules for Naming Variables
#
# ![image.png](attachment:43c5df42-96a2-4f9c-8220-9f68dd9be25f.png)

# %%
num1_  = 5
print(num1_)
# Out:
# 5

# %%
num1$  = 5
print(num1_$)

# %%
_num = 10
_num
# Out:
# 10

# %%
1num=20
1num
# Out:
#   Cell In[38], line 1
#     1num=20
#     ^
# SyntaxError: invalid decimal literal

# %%
num = 10
Num
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 2
#       1 num = 10
# ----> 2 Num
#
# NameError: name 'Num' is not defined

# %% [markdown]
# ### DataTypes
#
# ![image.png](attachment:d30b3f6b-b599-4216-a0d8-5eb1c8b33f3a.png)

# %%
name = 'SUMIT'
name
# Out:
# 'SUMIT'

# %%
name[2]='N'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 name[2]='N'
#
# TypeError: 'str' object does not support item assignment

# %%
name = 'SUNIT'
name
# Out:
# 'SUNIT'

# %%
num   = 10
num[1] = 1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[51], line 2
#       1 num   = 10
# ----> 2 num[1] = 1
#
# TypeError: 'int' object does not support item assignment

# %% [markdown]
# ### Operators
#
# ![image.png](attachment:56a49707-40b3-415d-a143-5df01dea9069.png)

# %%
### Arithmetic Operators

# %%
10  + 20
# Out:
# 30

# %%
10 + 20.5
# Out:
# 30.5

# %%
10 / 2  # Oputput type of division operator is alwasy float datatype
# Out:
# 5.0

# %%
10 / 3
# Out:
# 3.3333333333333335

# %%
a = 10
b = 2
c = a / b
print(type (c))
# Out:
# <class 'float'>

# %%
a = 10
b = 2
c = a // b  # Floor Division without reminder, to get only whole number
print(c)
print(type(c))
# Out:
# 5
# <class 'int'>

# %%
a = 10
b = 3
c = a % b  # Moduler Operator to get the reminder value   Real use case is , to check the number is odd or even.
print(c)
# Out:
# 1

# %%
10 ** 2  # 10 * 10
# Out:
# 100

# %%
Operator will evaluated from left to right 
** - evaluated from Right to left

# %%
10 + 20 + 30  -  5
# Out:
# 55

# %%
BODMAS Rule  # B - Bracket, O - order or power, D - Division, M - Multiplcation, A - addition, S - Subrattion

# %%
10 + 20 + (30  -  5)
# Out:
# 55

# %%
10 + (20 + 30)  -  5
# Out:
# 257

# %%
10 - 5 * 3 + 30
# Out:
# 25

# %%
(10 - 5) * 3 + 30
# Out:
# 45

# %%
### Assignment Operators

# %%
a = 10

# %%
a = 30
a += 10   # a = a + 10
print(a)
# Out:
# 40

# %%
### comparision Opeators  # Return the Boolean datatype (True(1) or False(0))

# %%
emp1 = 100

emp2 = 200

emp1 == emp2  # False
# Out:
# False

# %%
emp1 > emp2
# Out:
# False

# %%
emp1 < emp2  # 100 < 200
# Out:
# True

# %%
<  ( 10 < 10)  # Top value wont included
<=( 10 <=10  # top value will get included

# %%
 10 < 10  #Right hand side will take value as  9
# Out:
# False

# %%
10 <= 10
# Out:
# True

# %%
9 < 10
# Out:
# True

# %%
9 <= 10
# Out:
# True

# %%
## Logical Operators 

(10 == 10 ) and ('Training' == 'training')
# Out:
# False

# %%
(10 == 10 ) or ('Training' == 'training')  or (10 > 20)
# Out:
# True

# %%
(10 == 10 ) and ('Training' == 'Training') and (10< 20)
# Out:
# True
