# %%
print(45+5)
# Out:
# 50

# %%
#Multiplication
print(20*5)
# Out:
# 100

# %%
#division
print(100/3) # simple division float division
# Out:
# 33.333333333333336

# %%
 print(100//3) # floor division
print(45%4) # division remaining value
# Out:
# 33
# 1

# %%
print(20**2) #power value find
# Out:
# 400
